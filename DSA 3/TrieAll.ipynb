# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end = False

class Trie:
    def __init__(self):
        self.root = TrieNode()
    
    def  insert(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.is_end =True
    
    def search(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                return False
            node = node.children[char]
        return node.is_end
    
    def insert_suffix(self, suffix):
        for i in range(len(suffix)):
            sufix = suffix[i:]
            self.insert_suffix(sufix)
            
    def insert_suffix(self, sufix):
        node = self.root
        for char in sufix:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.is_end = True
    
    def search_suff(self, word):
        node =  self.root
        for char in word:
            if char not in node.children:
                return False
            node = node.children[char]
        return True
    
    def get_sugg(self, prefix):
        node = self.root
        for char in prefix:
            if char not in node.children:
                return []
            node = node.children[char]
        return self.all_sug(node, prefix)
    
    def all_sug(self, node, prefix):
        sugg=[]
        if node.is_end:
            sugg.append(prefix)
        for char, child in node.children.items():
            sugg.extend(self.all_sug(child, prefix+char))
        return sugg

tri = Trie()
tri.insert("apple")
tri.insert_suffix("animal")
tri.get_sugg("a")
# Out:
# ['apple', 'animal']

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end = False
    
class Trie:
    def __init__(self):
        self.root = TrieNode()
        
    def insert(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = self.children[char]
        node.is_end =True
    
    def search(self, word):
        node = self.root
        for char in node.children:
            return False
        node = node.children[char]
        return node.is_end
    
    def insertsuff(self, word):
        for i in range(len(word)):
            suffix = word[i:]
            self.insertsufix(suffix)
        
    def insertsufix(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.is_end = True
    
    def getsug(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                return []
            node = node.children[char]
        return self.getall(node, char)
    
    def getall(self, node, charr):
        sugg=[]
        if node.is_end:
            sugg.append(char)
        for char, child in node.children.items():
            sugg.extend(self.getall(child, charr+char))
